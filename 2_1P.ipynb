# %% [markdown]
# <a href="https://colab.research.google.com/github/spacee48/SIT719/blob/main/2_1P.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Section 1**

# %% [markdown]
# Instructions: In this task, you will be asked to perform some basic python operations using pandas and numpy libraries. Please write the code, execute and take a screenshot of the results of the completed outputs.

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

iris = pd.read_csv(url)
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.columns = ["sepal_length", "sepal_width", "petal_length", "petal_width", "class"]

print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
iris.loc[10:29, "petal_length"] = np.nan
iris.loc[10:29]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 10           4.8          3.4           NaN          0.2  Iris-setosa
# 11           4.8          3.0           NaN          0.1  Iris-setosa
# 12           4.3          3.0           NaN          0.1  Iris-setosa
# 13           5.8          4.0           NaN          0.2  Iris-setosa
# 14           5.7          4.4           NaN          0.4  Iris-setosa
# 15           5.4          3.9           NaN          0.4  Iris-setosa
# 16           5.1          3.5           NaN          0.3  Iris-setosa
# 17           5.7          3.8           NaN          0.3  Iris-setosa
# 18           5.1          3.8           NaN          0.3  Iris-setosa
# 19           5.4          3.4           NaN          0.2  Iris-setosa
# 20           5.1          3.7           NaN          0.4  Iris-setosa
# 21           4.6          3.6           NaN          0.2  Iris-setosa
# ...

# %%
iris.isnull().sum()
# Out:
# sepal_length     0
# sepal_width      0
# petal_length    20
# petal_width      0
# class            0
# dtype: int64

# %%
iris = iris.fillna(10.0)

print(iris.loc[10:29])
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 10           4.8          3.4          10.0          0.2  Iris-setosa
# 11           4.8          3.0          10.0          0.1  Iris-setosa
# 12           4.3          3.0          10.0          0.1  Iris-setosa
# 13           5.8          4.0          10.0          0.2  Iris-setosa
# 14           5.7          4.4          10.0          0.4  Iris-setosa
# 15           5.4          3.9          10.0          0.4  Iris-setosa
# 16           5.1          3.5          10.0          0.3  Iris-setosa
# 17           5.7          3.8          10.0          0.3  Iris-setosa
# 18           5.1          3.8          10.0          0.3  Iris-setosa
# 19           5.4          3.4          10.0          0.2  Iris-setosa
# 20           5.1          3.7          10.0          0.4  Iris-setosa
# 21           4.6          3.6          10.0          0.2  Iris-setosa
# ...

# %% [markdown]
# **Section 2**

# %% [markdown]
# Python contains libraries for data analysis including Pandas, NumPy and Matplotlib. Those libraries help in handling, processing and visualizing data efficiently.
#
#
# *   Pandas: used for handling data through DataFrames
# *   NumPy: provides arrays and mathematical operations
# *   Matploblit: used for data visualization and creating graphs and plots

# %% [markdown]
# Example

# %%
# importing the pandas library
import pandas as pd

# create a dictionary for location and population
# provide missing values
data = {'Location': ['Paris', 'London', None, 'Melbourne'],
        'Population': [8000, 2400, None, None]}
# convert to dataframe
df = pd.DataFrame(data)

# isnull() to check for missing vlaues
# sum() to count the total number of NaN values
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# Location      1
# Population    2
# dtype: int64

# %%
import pandas as pd

data = {'Location': ['Paris', 'London', 'Phnom Penh', 'Melbourne'],
        'Population': [8000, 2400, 23683, 764578]}
df = pd.DataFrame(data)

# filter the dataframe for data that is greater than 10000
filtered_df = df[df['Population'] > 10000]

print(filtered_df)
# Out:
#      Location  Population
# 2  Phnom Penh       23683
# 3   Melbourne      764578

# %%
import matplotlib.pyplot as plt

# creating lists
grades = ['HD', 'D', 'C', 'P']
scores = [100, 80,  65, 50]

# create a bar chart
plt.bar(grades, scores, color='skyblue')
# label the x-axis
plt.xlabel('Grades')
# label the y-axis
plt.ylabel('Scores')
plt.title('Grading System')

plt.show()
